# %% [markdown]
# <a href="https://colab.research.google.com/github/hasnathumein/ai-email/blob/master/ebay_review_exporter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Colab Python is working")
# Out:
# Colab Python is working
